# %% [markdown]
# # ENCODING

# %%
import pandas as pd
df1=pd.read_csv("train.csv")
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## ONE HOT ENCODING WITH DUMMIES(NOMINAL)

# %%
df1.dropna(inplace=True)
var=pd.get_dummies(df1.Embarked)

# %%
var
# Out:
#      C  Q  S
# 1    1  0  0
# 3    0  0  1
# 6    0  0  1
# 10   0  0  1
# 11   0  0  1
# ..  .. .. ..
# 871  0  0  1
# 872  0  0  1
# 879  1  0  0
# 887  0  0  1
# 889  1  0  0
#
# [183 rows x 3 columns]

# %% [markdown]
# ## ONE HOT ENCODING WITH SKLEARN(NOMINAL)

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
one=OneHotEncoder()

# %%
var=pd.DataFrame(one.fit_transform(df1[['Sex']]).toarray())

# %%
var
# Out:
#        0    1
# 0    1.0  0.0
# 1    1.0  0.0
# 2    0.0  1.0
# 3    1.0  0.0
# 4    1.0  0.0
# ..   ...  ...
# 178  1.0  0.0
# 179  0.0  1.0
# 180  1.0  0.0
# 181  1.0  0.0
# 182  0.0  1.0
#
# [183 rows x 2 columns]

# %%
import pandas as pd
df=pd.read_csv("merc.csv",usecols=["X0","X1","X2","X3","X4"])
df.head()
# Out:
#    X0 X1  X2 X3 X4
# 0   k  v  at  a  d
# 1   k  t  av  e  d
# 2  az  w   n  c  d
# 3  az  t   n  f  d
# 4  az  v   n  f  d

# %% [markdown]
# ## ONE HOT ENCODING WITH MANY CATEGORIES (NOMINAL)

# %%
top_10=df.X2.value_counts().head(10).index

# %%
top_10
# Out:
# Index(['as', 'ae', 'ai', 'm', 'ak', 'r', 'n', 's', 'f', 'e'], dtype='object')

# %%
df.X2
# Out:
# 0       at
# 1       av
# 2        n
# 3        n
# 4        n
#         ..
# 4204    as
# 4205     t
# 4206     r
# 4207     e
# 4208    ae
# Name: X2, Length: 4209, dtype: object

# %%
for i in top_10:
    df[i]=np.where(df["X2"]==i,1,0)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-104-6a91de33292e> in <module>
#       1 for i in top_10:
# ----> 2     df[i]=np.where(df["X2"]==i,1,0)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %% [markdown]
# ## ORDINAL NUMBER ENCODING(ORDINAL)

# %%
import pandas as pd
df4=pd.read_csv("merc.csv",usecols=["X1","X2","X3","X4"])
df4
# Out:
#      X1  X2 X3 X4
# 0     v  at  a  d
# 1     t  av  e  d
# 2     w   n  c  d
# 3     t   n  f  d
# 4     v   n  f  d
# ...  ..  .. .. ..
# 4204  s  as  c  d
# 4205  o   t  d  d
# 4206  v   r  a  d
# 4207  r   e  f  d
# 4208  r  ae  c  d
#
# [4209 rows x 4 columns]

# %%
ordinal=df4.X3.unique()
rankordinal=['a','b','c','d','e','f','g']

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
ord=OrdinalEncoder(categories=[rankordinal])

# %%
df4['new']=ord.fit_transform(df4[['X3']])

# %%
df4
# Out:
#      X1  X2 X3 X4  new
# 0     v  at  a  d  0.0
# 1     t  av  e  d  4.0
# 2     w   n  c  d  2.0
# 3     t   n  f  d  5.0
# 4     v   n  f  d  5.0
# ...  ..  .. .. ..  ...
# 4204  s  as  c  d  2.0
# 4205  o   t  d  d  3.0
# 4206  v   r  a  d  0.0
# 4207  r   e  f  d  5.0
# 4208  r  ae  c  d  2.0
#
# [4209 rows x 5 columns]

# %% [markdown]
# ## FREQUENCY OR COUNT ENCODING(NOMINAL)

# %%
data1=pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data',header=None)
data1.head()
# Out:
#    0                  1       2           3   4                    5   \
# 0  39          State-gov   77516   Bachelors  13        Never-married
# 1  50   Self-emp-not-inc   83311   Bachelors  13   Married-civ-spouse
# 2  38            Private  215646     HS-grad   9             Divorced
# 3  53            Private  234721        11th   7   Married-civ-spouse
# 4  28            Private  338409   Bachelors  13   Married-civ-spouse
#
#                    6               7       8        9     10  11  12  \
# 0        Adm-clerical   Not-in-family   White     Male  2174   0  40
# 1     Exec-managerial         Husband   White     Male     0   0  13
# 2   Handlers-cleaners   Not-in-family   White     Male     0   0  40
# 3   Handlers-cleaners         Husband   Black     Male     0   0  40
# 4      Prof-specialty            Wife   Black   Female     0   0  40
#
#                13      14
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %%
columns=[1,3,5,6,7,8,9,13]
data1=data1[columns]

# %%
data1.columns=['Employment','Degree','Status','Designation','family_job','Race','Sex','Country']

# %%
data1.head()
# Out:
#           Employment      Degree               Status         Designation  \
# 0          State-gov   Bachelors        Never-married        Adm-clerical
# 1   Self-emp-not-inc   Bachelors   Married-civ-spouse     Exec-managerial
# 2            Private     HS-grad             Divorced   Handlers-cleaners
# 3            Private        11th   Married-civ-spouse   Handlers-cleaners
# 4            Private   Bachelors   Married-civ-spouse      Prof-specialty
#
#        family_job    Race      Sex         Country
# 0   Not-in-family   White     Male   United-States
# 1         Husband   White     Male   United-States
# 2   Not-in-family   White     Male   United-States
# 3         Husband   Black     Male   United-States
# 4            Wife   Black   Female            Cuba

# %%
for column in data1.columns:
    print(column,":",len(data1[column].unique()))
# Out:
# Employment : 9
# Degree : 16
# Status : 7
# Designation : 15
# family_job : 6
# Race : 5
# Sex : 2
# Country : 42

# %%
country=data1.Country.value_counts().to_dict()

# %%
data1["encoded_country"]=data1.Country.map(country)
# Out:
# <ipython-input-174-c2fef92378a5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["encoded_country"]=data1.Country.map(country)

# %%
data1
# Out:
#               Employment       Degree               Status  \
# 0              State-gov    Bachelors        Never-married
# 1       Self-emp-not-inc    Bachelors   Married-civ-spouse
# 2                Private      HS-grad             Divorced
# 3                Private         11th   Married-civ-spouse
# 4                Private    Bachelors   Married-civ-spouse
# ...                  ...          ...                  ...
# 32556            Private   Assoc-acdm   Married-civ-spouse
# 32557            Private      HS-grad   Married-civ-spouse
# 32558            Private      HS-grad              Widowed
# 32559            Private      HS-grad        Never-married
# 32560       Self-emp-inc      HS-grad   Married-civ-spouse
#
#               Designation      family_job    Race      Sex         Country  \
# 0            Adm-clerical   Not-in-family   White     Male   United-States
# 1         Exec-managerial         Husband   White     Male   United-States
# ...
