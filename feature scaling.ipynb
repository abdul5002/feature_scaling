# %% [markdown]
#  # FEATURE SCALING

# %% [markdown]
# ## MIN_MAX_SCALER

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
df=pd.read_csv("train.csv",usecols=["Pclass","Survived","Age","Fare"])
df.head()
# Out:
#    Survived  Pclass   Age     Fare
# 0         0       3  22.0   7.2500
# 1         1       1  38.0  71.2833
# 2         1       3  26.0   7.9250
# 3         1       1  35.0  53.1000
# 4         0       3  35.0   8.0500

# %%
norm=MinMaxScaler()
df.Age.fillna(df.Age.median(),inplace=True)

# %%
data=pd.DataFrame(norm.fit_transform(df),columns=["Survived","Pclass","Age","Fare"])

# %%
data
# Out:
#      Survived  Pclass       Age      Fare
# 0         0.0     1.0  0.271174  0.014151
# 1         1.0     0.0  0.472229  0.139136
# 2         1.0     1.0  0.321438  0.015469
# 3         1.0     0.0  0.434531  0.103644
# 4         0.0     1.0  0.434531  0.015713
# ..        ...     ...       ...       ...
# 886       0.0     0.5  0.334004  0.025374
# 887       1.0     0.0  0.233476  0.058556
# 888       0.0     1.0  0.346569  0.045771
# 889       1.0     0.0  0.321438  0.058556
# 890       0.0     1.0  0.396833  0.015127
#
# [891 rows x 4 columns]

# %% [markdown]
# ## STANDARDIZATION

# %%
from sklearn.preprocessing import StandardScaler
std=StandardScaler()
df1=pd.read_csv("train.csv",usecols=["Pclass","Survived","Age","Fare"])
df1.Age.fillna(df.Age.median(),inplace=True)
df1.head()
data1=pd.DataFrame(std.fit_transform(df1),columns=["Survived","Pclass","Age","Fare"])

# %%
data1
# Out:
#      Survived    Pclass       Age      Fare
# 0   -0.789272  0.827377 -0.565736 -0.502445
# 1    1.266990 -1.566107  0.663861  0.786845
# 2    1.266990  0.827377 -0.258337 -0.488854
# 3    1.266990 -1.566107  0.433312  0.420730
# 4   -0.789272  0.827377  0.433312 -0.486337
# ..        ...       ...       ...       ...
# 886 -0.789272 -0.369365 -0.181487 -0.386671
# 887  1.266990 -1.566107 -0.796286 -0.044381
# 888 -0.789272  0.827377 -0.104637 -0.176263
# 889  1.266990 -1.566107 -0.258337 -0.044381
# 890 -0.789272  0.827377  0.202762 -0.492378
#
# [891 rows x 4 columns]

# %%
df.Fare.hist(bins=50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## ROBUST SCALER

# %%
df2=pd.read_csv("train.csv",usecols=["Pclass","Survived","Age","Fare"])
df2.Age.fillna(df.Age.median(),inplace=True)
df2.head()
# Out:
#    Survived  Pclass   Age     Fare
# 0         0       3  22.0   7.2500
# 1         1       1  38.0  71.2833
# 2         1       3  26.0   7.9250
# 3         1       1  35.0  53.1000
# 4         0       3  35.0   8.0500

# %%
from sklearn.preprocessing import RobustScaler
robust=RobustScaler()
data3=pd.DataFrame(robust.fit_transform(df2),columns=["Survived","Pclass","Age","Fare"])

# %%
data3.Age.hist(bins=25)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## MAX_ABS_SCALER

# %%
from sklearn.preprocessing import MaxAbsScaler
df4=pd.read_csv("train.csv",usecols=["Pclass","Survived","Age","Fare"])
df4.Age.fillna(df.Age.median(),inplace=True)
df4.head()
# Out:
#    Survived  Pclass   Age     Fare
# 0         0       3  22.0   7.2500
# 1         1       1  38.0  71.2833
# 2         1       3  26.0   7.9250
# 3         1       1  35.0  53.1000
# 4         0       3  35.0   8.0500

# %%
maxabs=MaxAbsScaler()
data4=pd.DataFrame(maxabs.fit_transform(df4),columns=["Survived","Pclass","Age","Fare"])

# %%
data4
# Out:
#      Survived    Pclass     Age      Fare
# 0         0.0  1.000000  0.2750  0.014151
# 1         1.0  0.333333  0.4750  0.139136
# 2         1.0  1.000000  0.3250  0.015469
# 3         1.0  0.333333  0.4375  0.103644
# 4         0.0  1.000000  0.4375  0.015713
# ..        ...       ...     ...       ...
# 886       0.0  0.666667  0.3375  0.025374
# 887       1.0  0.333333  0.2375  0.058556
# 888       0.0  1.000000  0.3500  0.045771
# 889       1.0  0.333333  0.3250  0.058556
# 890       0.0  1.000000  0.4000  0.015127
#
# [891 rows x 4 columns]
